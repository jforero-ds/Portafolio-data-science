# %%
#Celda 1 - importas librerias
import requests     #para hacer llamadas http a la API
import json         #Para guardar la respuesta en formato JSOM
import os           #para manejar rutas de archivo y carpetas
